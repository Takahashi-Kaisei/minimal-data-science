# %% [markdown]
# # このnotebookでは
#
# GPUサーバーでtorchが正しくimportできるか。
#
# cudaを認識するかをテストする。
#
# 結論:
#
# OK

# %%
import torch
import numpy as np

# %%
torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# device(type='cuda')

# %%
torch.device("mps" if torch.mps.is_available() else "cpu")
# Out:
# device(type='cpu')
