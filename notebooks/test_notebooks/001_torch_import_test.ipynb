# %% [markdown]
# # このnotebookでは
#
# ローカルでtorchが正しくimportできるか。
#
# mpsを認識するかをテストする。
#
# 結論:
#
# OK

# %%
import torch
import numpy as np

# %%
torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# device(type='cpu')

# %%
torch.device("mps" if torch.mps.is_available() else "cpu")
# Out:
# device(type='mps')
